# %%
import wmi

# %%
# !pip install wmi

# %%
import glob

# %%
glob?
# Out:
# Type:        module
# String form: <module 'glob' from 'C:\\Users\\User1\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\glob.py'>
# File:        c:\users\user1\appdata\local\programs\python\python311\lib\glob.py
# Docstring:   Filename globbing utility.

# %%
import json
import sys
import os
import pprint

# %%
data = {
        "GPS_serial_port":"COM4",
        "cam_type":"cv",
        "logging_active":True
}
with open("config.json", "wt") as cfg:
    json.dump(data, cfg)
print("Config written")
# Out:
# Config written

# %%
pprint.pp(data)
# Out:
# {'GPS_serial_port': 'COM4', 'cam_type': 'cv', 'logging_active': True}

# %%
cfg = {}
with open("config.json", "rt") as cfg:
    cfg = json.load(cfg)
    pprint.pp(cfg)
# Out:
# {'GPS_serial_port': 'COM4', 'cam_type': 'cv', 'logging_active': True}

# %%
cfg.get("cam_type", "not defined")
# Out:
# 'cv'

# %%
cfg.get("GPS_serial_port", "not defined")
# Out:
# 'COM4'

# %%
cfg.get("logging_active", "not defined")
# Out:
# True

# %%
os.path.isfile("config.json")
# Out:
# True

# %%
import av_cam

# %%
cam = av_cam.MainThread()

# %%
cam.start()
# Out:
# 2023-03-15 10:10:38,289 | Info     | Thread 'MainThread' started.
# 2023-03-15 10:10:38,293 | Info     | Starting VimbaPython: 1.2.1 (using VimbaC: 1.9.1, VimbaImageTransform: 1.6)
# 2023-03-15 10:10:40,671 | Info     | Thread 'FrameProducer(DEV_1AB22C027351)' started.
# 2023-03-15 10:10:40,671 | Info     | Thread 'FrameConsumer' started.
# 2023-03-15 10:10:41,047 | Error    | Called 'set()' of Feature 'Height' with invalid value. 4112 is not within [8, 3008].
# 2023-03-15 10:10:41,057 | Info     | Camera DEV_1AB22C027351: Failed to set value of Feature 'Height' to '4112': Using nearest valid value '3008'. Note that, this causes resizing during processing, reducing the frame rate.
# 2023-03-15 10:10:48,984 | Info     | Thread 'FrameConsumer' terminated.
# 2023-03-15 10:10:49,156 | Info     | Thread 'FrameProducer(DEV_1AB22C027351)' terminated.
# 2023-03-15 10:10:49,625 | Info     | Thread 'MainThread' terminated.

# %%
import av_cam as av

# %%
cam = av.MainThread()

# %%
cam.start()
# Out:
# 2023-03-15 12:10:59,683 | Info     | Thread 'MainThread' started.
# 2023-03-15 12:10:59,686 | Info     | Starting VimbaPython: 1.2.1 (using VimbaC: 1.9.1, VimbaImageTransform: 1.6)
# 2023-03-15 12:11:00,328 | Info     | Thread 'FrameProducer(DEV_1AB22C027351)' started.
# 2023-03-15 12:11:00,328 | Info     | Thread 'FrameConsumer' started.
# 2023-03-15 12:11:00,843 | Error    | Called 'set()' of Feature 'Height' with invalid value. 4112 is not within [8, 3008].
# 2023-03-15 12:11:00,861 | Info     | Camera DEV_1AB22C027351: Failed to set value of Feature 'Height' to '4112': Using nearest valid value '3008'. Note that, this causes resizing during processing, reducing the frame rate.

# %%
frame = cam.getFrame()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 frame = cam.getFrame()
#
# AttributeError: 'MainThread' object has no attribute 'getFrame'

# %%
cam.join(1)

# %%
cam.getName()
# Out:
# C:\Users\User1\AppData\Local\Temp\ipykernel_11108\1215651027.py:1: DeprecationWarning: getName() is deprecated, get the name attribute instead
#   cam.getName()
# 'Thread-5'

# %%
import time

# %%
lastTime = time.time()

# %%
now = time.time()

# %%
now - lastTime
# Out:
# 7.083693981170654

# %%
1/_
# Out:
# 0.14116928295577494

# %%
round(_,2)
# Out:
# 0.14
